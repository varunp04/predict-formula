# %% [markdown]
# # data analysis notebook

# %%
import numpy as np
import pandas as pd
from data import gatherData
from utils import load_config_file

# %%
config = load_config_file("config.yml")

# %%
gather_data_obj = gatherData(config=config)

# %%
(
    lap_times_df,
    pit_stops_df,
    qualifying_df,
    races_df,
    results_df,
    sprint_results_df,
    status_df,
) = gather_data_obj.load_data()

# %%
lap_times_race_driver = lap_times_df[
    (lap_times_df["driverId"] == driver_id) & (lap_times_df["raceId"] == race_id)
]
lap_times_race_driver = lap_times_race_driver.reset_index(drop=True)
lap_times_race_driver
# Out:
#     raceId  driverId  lap  position      time  milliseconds
# 0      841       153    1        21  2:13.879        133879
# 1      841       153    2        21  1:40.659        100659
# 2      841       153    3        21  1:33.293         93293
# 3      841       153    4        21  1:33.144         93144
# 4      841       153    5        21  1:33.320         93320
# 5      841       153    6        21  1:33.570         93570
# 6      841       153    7        19  1:35.336         95336
# 7      841       153    8        18  1:34.601         94601
# 8      841       153    9        18  1:33.882         93882
# 9      841       153   10        17  1:33.983         93983
# 10     841       153   11        17  1:35.061         95061
# 11     841       153   12        16  1:35.074         95074
# 12     841       153   13        15  1:34.964         94964
# 13     841       153   14        14  1:34.918         94918
# 14     841       153   15        12  1:35.373         95373
# ...

# %%
qualifying_race_driver = qualifying_df[
    (qualifying_df["driverId"] == driver_id) & (qualifying_df["raceId"] == race_id)
]
qualifying_race_driver = qualifying_race_driver.reset_index(drop=True)
qualifying_race_driver
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0       4548     841       153              5      19        12  1:26.620
#
#          q2  q3
# 0  1:26.103  \N

# %%
pit_stops_race_driver = pit_stops_df[
    (pit_stops_df["driverId"] == driver_id) & (pit_stops_df["raceId"] == race_id)
]
pit_stops_race_driver = pit_stops_race_driver.reset_index(drop=True)
pit_stops_race_driver
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841       153     2   17  17:31:06   24.463         24463
# 2     841       153     3   35  17:59:45   26.348         26348

# %%
races_race = races_df[races_df["raceId"] == race_id]
races_race = races_race.reset_index(drop=True)
races_race
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0     841  2011      1          1  Australian Grand Prix  2011-03-27
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2011_Australian_G...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time
# 0          \N          \N

# %%
results_race_driver = results_df[
    (results_df["raceId"] == race_id) & (results_df["driverId"] == driver_id)
]
results_race_driver = results_race_driver.reset_index(drop=True)
results_race_driver
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0     20789     841       153              5     19    12       11
#
#   positionText  positionOrder  points  laps time milliseconds fastestLap rank  \
# 0           11             11     0.0    57   \N           \N         41   10
#
#   fastestLapTime fastestLapSpeed  statusId
# 0       1:30.467         211.025        11

# %%
sprint_race_driver = sprint_results_df[
    (sprint_results_df["raceId"] == race_id)
    & (sprint_results_df["driverId"] == driver_id)
]
sprint_race_driver = sprint_race_driver.reset_index(drop=True)
sprint_race_driver
# Out:
# Empty DataFrame
# Columns: [resultId, raceId, driverId, constructorId, number, grid, position, positionText, positionOrder, points, laps, time, milliseconds, fastestLap, fastestLapTime, statusId]
# Index: []

# %%
laptimes_by_driver = lap_times_df[lap_times_df["driverId"] == driver_id]
laptimes_by_driver = laptimes_by_driver.reset_index(drop=True)
races_df_imporant_columns = ["raceId", "year", "round", "circuitId", "name", "date"]

# %%
merged_df = pd.merge(
    lap_times_df, races_df[races_df_imporant_columns], on="raceId", how="left"
)

# %%
merged_df
# Out:
#         raceId  driverId  lap  position      time  milliseconds  year  round  \
# 0          841        20    1         1  1:38.109         98109  2011      1
# 1          841        20    2         1  1:33.006         93006  2011      1
# 2          841        20    3         1  1:32.713         92713  2011      1
# 3          841        20    4         1  1:32.803         92803  2011      1
# 4          841        20    5         1  1:32.342         92342  2011      1
# ...        ...       ...  ...       ...       ...           ...   ...    ...
# 551737    1110       817   40        17  1:54.361        114361  2023     12
# 551738    1110       817   41        17  1:53.367        113367  2023     12
# 551739    1110       817   42        16  1:55.247        115247  2023     12
# 551740    1110       817   43        16  1:52.115        112115  2023     12
# 551741    1110       817   44        16  1:52.265        112265  2023     12
#
# ...
